# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.rcParams['font.family'] = 'Malgun Gothic'              #Window 용
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False



df = pd.read_excel('연령별인구현황2024_10.xlsx',skiprows=3,usecols='B,E:Y',nrows=1,index_col='행정기관')
len(df.columns)

# row에 있는 열
# df.loc['전국  '][0]
# df.iloc[0][0]


df.iloc[0] = df.iloc[0].str.replace(",","").astype(int)


f_df = pd.read_excel('연령별인구현황2024_10.xlsx',skiprows=3,usecols='B,AB:AV',nrows=1,index_col='행정기관')

f_df.iloc[0] = f_df.iloc[0].str.replace(',','').astype(int)

plt.barh(df.columns,df.iloc[0])
plt.barh(f_df.columns,f_df.iloc[0])
# Out:
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <BarContainer object of 21 artists>
