# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.rcParams['font.family'] = 'Malgun Gothic'              #Window 용
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False


x = [1,2,3,4,5,6,7,8]
y = [1,2,3,4,5,6,7,8]
y2 = [1,2,2,2,3,5,6,3]
y3 = [1,3,3,6,2,5,2,7]

plt.plot(x,y, label ='인원증가', linewidth =5, marker = 'v', markersize = 10, markeredgecolor = 'red', linestyle = '-.')
# plt.plot(x,y2, label ='비용증가', marker = 'o', markersize = 10,markerfacecolor = 'green', markeredgecolor = 'yellow', alpha = 0.2, linestyle = ':')
plt.plot(x,y2, label ='비용증가', marker = 'o', ms = 10, mfc = 'green', markeredgecolor = 'yellow', alpha = 0.2, ls = ':')

plt.plot(x,y3, 'bv:', label = 'test')

plt.title("line", size = 30)

plt.legend(loc= 'upper center')
plt.legend(loc= [0.5,0.2])

plt.show()
