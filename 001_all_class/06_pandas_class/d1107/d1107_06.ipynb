# %%
import pandas as pd

df = pd.read_excel('연령별인구현황01.xlsx',skiprows=3)
# df.iloc[0]
# df[0:1]

df_w = pd.read_excel('연령별인구현황02.xlsx',skiprows=3, index_col='행정기관')
# df.columns
# df_w.columns
# df['0~9세']

df_w
# Out:
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                행정기관코드       총 인구수     연령구간인구수       0~4세       5~9세  \
# 행정기관
# 전국                  0  51,238,450  51,238,450  1,276,904  1,888,125
# 서울특별시      1100000000   9,343,304   9,343,304    203,598    283,860
# 부산광역시      2600000000   3,271,062   3,271,062     71,543    111,841
# 대구광역시      2700000000   2,364,892   2,364,892     55,132     88,120
# 인천광역시      2800000000   3,017,928   3,017,928     81,275    114,845
# 광주광역시      2900000000   1,410,548   1,410,548     36,479     57,300
# 대전광역시      3000000000   1,440,094   1,440,094     38,397     53,858
# ...
